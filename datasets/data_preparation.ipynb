# %%
# Simulate data
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from mambular.models import MambularRegressor

# Set random seed for reproducibility
np.random.seed(0)

# Number of samples
n_samples = 20369
n_features = 5



# Create a DataFrame to store the data
data = pd.read_csv('/mnt/j/workspace/2025math/datasets/valid_all_txbf.csv')

# %%
data.drop(columns=['Unnamed: 0','dfx_time','beamforming_en','source_file', 'csi_time'], inplace=True)

# %%
data.head()
# Out:
#                                     csi_matrix_r0_c0  \
# 0  [(1.7677929373027342e-06+2.6467788700171493e-0...
# 1  [(-8.428248377466868e-06-7.1763331213986895e-0...
# 2  [(9.057424232485614e-06+9.906931657196946e-06j...
# 3  [(-7.984002593560119e-06-1.067142830315715e-05...
# 4  [(1.055150001221062e-05+1.3433548573967696e-05...
#
#                                     csi_matrix_r0_c1  \
# 0  [(-2.749900124693142e-06+1.826719368546159e-05...
# 1  [(-4.652787408379371e-06-5.7765538587082856e-0...
# 2  [(4.917571148681093e-06+7.980583834964206e-06j...
# 3  [(-4.200733390729343e-06-8.492787072561498e-06...
# 4  [(5.443869505541139e-06+1.005514720435246e-05j...
#
#                                     csi_matrix_r0_c2  \
# 0  [(9.354570959893636e-06-8.053278936601346e-06j...
# 1  [(1.675792075051892e-07+4.9189426202993775e-06...
# 2  [(1.1246999707445808e-06-5.874762613144566e-06...
# 3  [(-2.165595474723823e-06+5.8053613629644645e-0...
# 4  [(2.449741277493513e-06-7.925633544831954e-06j...
#
#                                     csi_matrix_r0_c3  \
# 0  [(-8.593437889666069e-07-3.6411623972499376e-0...
# 1  [(9.660448432652083e-06+1.0242046858699503e-05...
# 2  [(-1.1211105027528429e-05-1.429804750042313e-0...
# 3  [(9.65385934515439e-06+1.5328763149400552e-05j...
# 4  [(-1.3001241289704137e-05-1.8557190461535827e-...
#
#                                     csi_matrix_r1_c0  \
# 0  [(3.5793777377015286e-05-1.0809636646172654e-0...
# 1  [(-5.221907596877523e-06+1.3667629530091006e-0...
# 2  [(1.1617697511030731e-05-1.4279656621018232e-0...
# 3  [(-1.278221023358884e-05+1.3153659077983732e-0...
# 4  [(1.2564969831874989e-05-1.9034592596372324e-0...
#
#                                     csi_matrix_r1_c1  \
# 0  [-6.897978248919514e-06j, (4.76314875178434e-0...
# 1  [(2.0988374585520587e-06+1.863767663194228e-06...
# 2  [(-1.1143084646459313e-06-2.7857711616148286e-...
# 3  [(8.958472129523803e-07+2.600141910764226e-06j...
# 4  [(-1.4169008533816478e-06-3.4219492308085076e-...
#
#                                     csi_matrix_r1_c2  \
# 0  [(1.2239705307534017e-05+9.673993885679806e-07...
# 1  [(-3.828279524398956e-06+3.4924655310306253e-0...
# 2  [(6.3350499749315e-06-1.9603574840993238e-06j)...
# 3  [(-6.9482783833867545e-06+1.136196465207897e-0...
# 4  [(7.966725552976057e-06-3.047673533688827e-06j...
#
#                                     csi_matrix_r1_c3  noise_floor  \
# 0  [(-3.0409989475419564e-05+1.6403728762674454e-...       -95.00
# 1  [(7.001721761729667e-06-1.0108001200386714e-05...       -95.00
# 2  [(-1.2216122427229471e-05+9.636704684993518e-0...       -94.75
# 3  [(1.2498161117286867e-05-9.176971449756092e-06...       -95.25
# 4  [(-1.4516550252570465e-05+1.368779692323403e-0...       -95.50
#
#       terminal_id  ...   non_ddx_p95   non_ddx_med  non_spec_entropy  \
# 0  341c-f0d4-70be  ...  3.637979e-12  0.000000e+00          4.735948
# 1  341c-f0d4-70be  ...  6.821210e-13  0.000000e+00          4.727001
# 2  341c-f0d4-70be  ...  1.364242e-12  0.000000e+00          4.741703
# 3  341c-f0d4-70be  ...  1.818989e-12  0.000000e+00          4.141526
# 4  341c-f0d4-70be  ...  1.864464e-12  4.547474e-13          4.720391
#
#    non_spec_flatness  non_spec_rolloff      pdp_peak    pdp_energy    pdp_rms  \
# 0           0.946866          0.900826  3.930754e-10  1.877357e-09  53.360939
# 1           1.849677          0.909091  6.164853e-11  2.975410e-10  53.237683
# 2           1.147422          0.900826  9.797382e-11  4.715707e-10  53.179414
# 3           2.398012          0.950413  1.078702e-10  4.715707e-10  53.172102
# 4           0.969757          0.909091  1.531022e-10  7.473892e-10  53.199337
#
#                                     H_merged_complex  diagnose_sinr_flat_ratio
# 0  [[[[1.7677929373027342e-06, 2.6467788700171493...              3.384281e-16
# 1  [[[[-8.428248377466868e-06, -7.176333121398689...              2.795190e-16
# 2  [[[[9.057424232485614e-06, 9.906931657196946e-...              3.024057e-16
# 3  [[[[-7.984002593560119e-06, -1.067142830315715...              3.505937e-16
# 4  [[[[1.055150001221062e-05, 1.3433548573967696e...              3.935015e-16
#
# [5 rows x 144 columns]

# %%
import numpy as np, pandas as pd, ast, json, re

try:
    from tqdm import tqdm
    TQDM = True
except Exception:
    TQDM = False

from pretab.preprocessor import Preprocessor  # pip install pretab

# ---------- 基础解析（无修改） ----------
def safe_literal_eval(s):
    if s is None: return None
    if isinstance(s, (list, tuple, np.ndarray, dict)): return s
    if not isinstance(s, str): return s
    t = s.strip()
    t = re.sub(r'^\s*array\s*\(', '(', t)  # 去掉 array(
    try:
        return ast.literal_eval(t)
    except Exception:
        try:
            return json.loads(t)
        except Exception:
            return s

def parse_h_merged_complex(s, expect_shape=(122,2,4,2)):
    obj = safe_literal_eval(s)
    try:
        arr = np.asarray(obj)
        if arr.ndim != 4 or arr.shape[-1] != 2:
            flat = np.asarray(obj).reshape(-1)
            T = int(np.prod(expect_shape))
            if flat.size < T: return None
            arr = flat[:T].reshape(*expect_shape)
        return arr[...,0] + 1j*arr[...,1]  # [K,2,4]
    except Exception:
        return None

def parse_complex_series(s):
    v = safe_literal_eval(s)
    try:
        return np.array(v, dtype=complex).reshape(-1)
    except Exception:
        try:
            a = np.asarray(v)
            if a.ndim >= 1 and a.shape[-1] == 2:
                return (a[...,0] + 1j*a[...,1]).reshape(-1).astype(complex)
        except Exception:
            pass
        nums = re.findall(r'[-+]?\d*\.?\d+(?:[eE][-+]?\d+)?', str(s))
        if len(nums) == 0: return None
        return np.array([float(x) for x in nums], dtype=float).reshape(-1) + 0j

# ---------- 特征提取（无修改） ----------
def feats_h_svd(h_complex, top_singular=2):
    if h_complex is None or h_complex.size == 0: return None
    try:
        K = h_complex.shape[0]
        svs = np.zeros((K, top_singular), dtype=float)
        for k in range(K):
            s = np.linalg.svd(h_complex[k], compute_uv=False)
            s = s[:top_singular]
            if s.size < top_singular:
                s = np.pad(s, (0, top_singular - s.size))
            svs[k] = s
        out = []
        for i in range(top_singular):
            si = svs[:, i]
            out += [float(si.mean()), float(si.std()), float(si.max())]
        mag = np.abs(h_complex).reshape(K, -1)
        phs = np.angle(h_complex).reshape(K, -1)
        out += [float(mag.mean()), float(mag.std()), float(phs.std())]
        return np.array(out, dtype=float)
    except Exception:
        return None

def h_feature_names(top_singular=2):
    names = []
    for i in range(top_singular):
        names += [f"h_sv{i+1}_mean", f"h_sv{i+1}_std", f"h_sv{i+1}_max"]
    names += ["h_mag_mean","h_mag_std","h_phase_std"]
    return names

def feats_complex_series(z):
    if z is None or z.size == 0: return None
    try:
        mag = np.abs(z); phs = np.angle(z)
        p05, p50, p95 = np.percentile(mag, [5,50,95])
        base = [
            float(len(mag)),
            float(mag.mean()), float(mag.std()), float(mag.min()), float(mag.max()),
            float(p05), float(p50), float(p95),
            float(phs.std())
        ]
        nfft = int(2**np.ceil(np.log2(max(8, mag.size))))
        A = np.abs(np.fft.rfft(mag, n=nfft))
        P = A**2; E = float(P.sum())
        if E > 0:
            p = P / E
            H = float(-(p*np.log(p+1e-12)).sum())
            flat = float(np.exp(np.mean(np.log(P+1e-12))) / (P.mean()+1e-12))
            cutoff = float(np.searchsorted(np.cumsum(P), 0.85*E) / len(P))
        else:
            H = flat = cutoff = 0.0
        return np.array(base + [E, H, flat, cutoff], dtype=float)
    except Exception:
        return None

def complex_series_feature_names(prefix):
    return [
        f"{prefix}_len",
        f"{prefix}_mag_mean", f"{prefix}_mag_std", f"{prefix}_mag_min", f"{prefix}_mag_max",
        f"{prefix}_mag_p05", f"{prefix}_mag_p50", f"{prefix}_mag_p95",
        f"{prefix}_phase_std",
        f"{prefix}_spec_energy", f"{prefix}_spec_entropy", f"{prefix}_spec_flatness", f"{prefix}_spec_rolloff",
    ]

CSI_COLS = [
    "csi_matrix_r0_c0","csi_matrix_r0_c1","csi_matrix_r0_c2","csi_matrix_r0_c3",
    "csi_matrix_r1_c0","csi_matrix_r1_c1","csi_matrix_r1_c2","csi_matrix_r1_c3"
]

def make_full_dataframe(df: pd.DataFrame, y_col="mcs", verbose=True) -> pd.DataFrame:
    N = len(df)

    # 1) H_merged_complex 特征提取（无修改）
    if verbose: print("[1/6] H_merged_complex → SVD 聚合")
    h_names = h_feature_names(2)
    H_block = np.full((N, len(h_names)), np.nan, dtype=float)
    H_ok = np.zeros(N, dtype=bool)
    if "H_merged_complex" in df.columns:
        it = df["H_merged_complex"].tolist()
        rng = tqdm(it) if TQDM and verbose else it
        for i, s in enumerate(rng):
            Hc = parse_h_merged_complex(s, (122,2,4,2))
            feats = feats_h_svd(Hc, top_singular=2)
            if feats is not None:
                H_block[i] = feats; H_ok[i] = True
    else:
        if verbose: print("   [跳过] 缺列 H_merged_complex")
    H_df = pd.DataFrame(H_block, columns=h_names, index=df.index)
    H_df.loc[~H_ok, :] = np.nan
    if verbose: print(f"   成功：{H_ok.sum()}/{N}")

    # 2) 8 路 CSI 特征提取（无修改）
    if verbose: print("[2/6] CSI 复数序列 → 统计+谱")
    csi_frames = []; csi_ok_mat = []
    for col in CSI_COLS:
        if col not in df.columns:
            if verbose: print(f"   [跳过] 缺列 {col}")
            continue
        names = complex_series_feature_names(col)
        block = np.full((N, len(names)), np.nan, dtype=float)
        ok = np.zeros(N, dtype=bool)
        it = df[col].tolist()
        rng = tqdm(it) if TQDM and verbose else it
        for i, s in enumerate(rng):
            z = parse_complex_series(s)
            feats = feats_complex_series(z)
            if feats is not None:
                block[i] = feats; ok[i] = True
        csi_frames.append(pd.DataFrame(block, columns=names, index=df.index))
        csi_ok_mat.append(ok)
        if verbose: print(f"   {col}: 成功 {ok.sum()}/{N}")
    CSI_df = pd.concat(csi_frames, axis=1) if csi_frames else pd.DataFrame(index=df.index)
    csi_any_ok = np.any(np.column_stack(csi_ok_mat), axis=1) if csi_ok_mat else np.zeros(N, dtype=bool)

    # 3) 原始数值 & 类别 & 元信息（无修改）
    if verbose: print("[3/6] 拼接原始数值/类别/元信息")
    exclude = set(["H_merged_complex"] + [c for c in CSI_COLS if c in df.columns] + ([y_col] if y_col in df.columns else []))
    num_cols_raw = [c for c in df.columns if (c not in exclude and pd.api.types.is_numeric_dtype(df[c]))]
    cat_cols_raw = [c for c in ["terminal_id"] if c in df.columns]
    num_df = df[num_cols_raw].copy() if num_cols_raw else pd.DataFrame(index=df.index)
    cat_df = df[cat_cols_raw].copy() if cat_cols_raw else pd.DataFrame(index=df.index)

    # 4) 行过滤 & processed_from（无修改）
    if verbose: print("[4/6] 逐行筛选：至少 H 或任一 CSI 成功")
    row_ok = H_ok | csi_any_ok
    kept = int(row_ok.sum())
    if verbose: print(f"   保留 {kept}/{N} 行")
    # 标注来源
    processed_from = []
    for i in range(N):
        if not row_ok[i]: processed_from.append("")
        else:
            tags = []
            if H_ok[i]: tags.append("H_svd")
            for j, col in enumerate([c for c in CSI_COLS if c in df.columns]):
                if csi_ok_mat and csi_ok_mat[j][i]:
                    tags.append(col)
            processed_from.append(",".join(tags))
    meta_df = pd.DataFrame({"processed_from": processed_from}, index=df.index)

    # 仅保留成功行（无修改）
    H_df = H_df.loc[row_ok]
    CSI_df = CSI_df.loc[row_ok]
    num_df = num_df.loc[row_ok]
    cat_df = cat_df.loc[row_ok]
    meta_df = meta_df.loc[row_ok]
    y = df.loc[row_ok, y_col].values.reshape(-1, 1) if y_col in df.columns else None

    # 5) PreTab 编码：核心修改处（任务类型从 regression 改为 classification）
    if verbose: print("[5/6] PreTab 编码：数值(ple) / 分类(one-hot) + 预清洗（分类任务适配）")

    # —— 数值部分：拼接后做预清洗（无修改，仅修改后续Preprocessor任务类型） —— #
    X_num_in = pd.concat([H_df, CSI_df, num_df], axis=1)

    # (a) 列名全部转字符串 & 去重（无修改）
    def _uniq_names(cols):
        seen = {}
        out = []
        for c in cols.astype(str):
            if c not in seen:
                seen[c] = 1
                out.append(c)
            else:
                k = seen[c]; seen[c] += 1
                out.append(f"{c}__dup{k}")
        return out
    X_num_in.columns = _uniq_names(pd.Index(X_num_in.columns))

    # (b) 值清洗：inf->NaN，全部转 float32（无修改）
    X_num_in = X_num_in.replace([np.inf, -np.inf], np.nan).astype("float32")

    # (c) 删掉全 NaN 列（无修改）
    all_nan_cols = X_num_in.columns[X_num_in.isna().all(0)]
    if len(all_nan_cols) and verbose:
        print(f"   [数值] 删除全NaN列: {len(all_nan_cols)}")
    X_num_in = X_num_in.drop(columns=list(all_nan_cols))

    # (d) 删掉常数列（无修改）
    nunique = X_num_in.nunique(dropna=True)
    const_cols = nunique[nunique <= 1].index.tolist()
    if len(const_cols) and verbose:
        print(f"   [数值] 删除常数列: {len(const_cols)}")
    X_num_in = X_num_in.drop(columns=const_cols)

    # y → 1D（无修改：分类任务接受整数类别标签，与原格式兼容）
    y_1d = y.ravel() if y is not None and y.ndim == 2 and y.shape[1] == 1 else (y if y is not None else None)

    # 数值路配置（全部 ple，无修改）
    num_cfg = {c: "ple" for c in X_num_in.columns}

    # —— 分类部分：同样处理列名（无修改） —— #
    X_cat_in = cat_df.copy()
    if X_cat_in.shape[1] > 0:
        X_cat_in.columns = _uniq_names(pd.Index(X_cat_in.columns))
    cat_cfg = {c: "one-hot" for c in X_cat_in.columns}

    # 6) 编码并汇总：核心修改处（任务类型切换）
    if verbose: print("[6/6] 汇总编码结果 → DataFrame（分类任务适配）")

    frames = []
    # 数值路：Preprocessor 任务类型从 regression 改为 classification
    try:
        if X_num_in.shape[1] > 0:
            # 关键修改1：task="classification"（原 regression）
            pre_num = Preprocessor(feature_preprocessing=num_cfg, task="classification")
            X_num_dict = pre_num.fit_transform(X_num_in, y=y_1d)
            for col, arr in X_num_dict.items():
                arr = np.asarray(arr)
                if arr.ndim == 1:
                    frames.append(pd.DataFrame(arr, columns=[f"{col}__0"], index=X_num_in.index))
                else:
                    frames.append(pd.DataFrame(arr,
                        columns=[f"{col}__{i}" for i in range(arr.shape[1])],
                        index=X_num_in.index))
    except Exception as e:
        # 回退逻辑（无修改，分类任务下用原始数值特征仍兼容）
        if verbose:
            print("   [警告] 数值路 PreTab 失败，将使用未编码的清洗数值特征返回。")
            print("   错误信息:", repr(e))
            bad_cols = []
            for c in X_num_in.columns:
                s = X_num_in[c]
                if s.isna().all() or (s.nunique(dropna=True) <= 1):
                    bad_cols.append(c)
            if bad_cols:
                print(f"   [线索] 可疑列(全NaN/常数): {bad_cols[:10]}{'...' if len(bad_cols)>10 else ''}")
        frames.append(X_num_in.add_prefix("raw_"))

    # 分类路：Preprocessor 任务类型从 regression 改为 classification
    try:
        if X_cat_in.shape[1] > 0:
            # 关键修改2：task="classification"（原 regression）
            pre_cat = Preprocessor(feature_preprocessing=cat_cfg, task="classification")
            X_cat_dict = pre_cat.fit_transform(X_cat_in, y=y_1d)
            for col, arr in X_cat_dict.items():
                arr = np.asarray(arr)
                if arr.ndim == 1:
                    frames.append(pd.DataFrame(arr, columns=[f"{col}__0"], index=X_cat_in.index))
                else:
                    frames.append(pd.DataFrame(arr,
                        columns=[f"{col}__{i}" for i in range(arr.shape[1])],
                        index=X_cat_in.index))
    except Exception as e:
        # 回退逻辑（无修改，pd.get_dummies 是分类任务常用编码）
        if verbose:
            print("   [警告] 分类路 PreTab 失败，将使用未编码的原始类别列返回。")
            print("   错误信息:", repr(e))
        if X_cat_in.shape[1] > 0:
            frames.append(pd.get_dummies(X_cat_in, dummy_na=True, prefix="rawcat"))

    # 汇总（无修改）
    X_out = pd.concat(frames, axis=1) if frames else pd.DataFrame(index=X_num_in.index)
    X_out.index = X_num_in.index

    # processed_from 与 y（无修改，保留类别标签列）
    X_out["processed_from"] = meta_df.loc[X_out.index, "processed_from"].values
    if y_1d is not None:
        X_out[y_col] = y_1d

    if verbose:
        print("   数值路列数(输入):", X_num_in.shape[1])
        print("   分类路列数(输入):", X_cat_in.shape[1])
        print("完成 ✅ 输出形状：", X_out.shape)
        # 新增：打印类别标签分布（帮助验证分类任务适配）
        if y_1d is not None:
            print(f"   类别标签({y_col})分布:")
            print(pd.Series(y_1d).value_counts().sort_index())
    return X_out

# %%
full_df = make_full_dataframe(data, y_col="mcs", verbose=True)
# Out:
# [1/6] H_merged_complex → SVD 聚合
# 100%|██████████| 20369/20369 [03:37<00:00, 93.65it/s]
#    成功：20369/20369
# [2/6] CSI 复数序列 → 统计+谱
# 100%|██████████| 20369/20369 [00:10<00:00, 1900.27it/s]
#    csi_matrix_r0_c0: 成功 20369/20369
# 100%|██████████| 20369/20369 [00:11<00:00, 1790.86it/s]
#    csi_matrix_r0_c1: 成功 20369/20369
# 100%|██████████| 20369/20369 [00:11<00:00, 1833.67it/s]
#    csi_matrix_r0_c2: 成功 20369/20369
# 100%|██████████| 20369/20369 [00:11<00:00, 1765.24it/s]
#    csi_matrix_r0_c3: 成功 20369/20369
# 100%|██████████| 20369/20369 [00:11<00:00, 1824.49it/s]
#    csi_matrix_r1_c0: 成功 20369/20369
# 100%|██████████| 20369/20369 [00:10<00:00, 1860.54it/s]
#    csi_matrix_r1_c1: 成功 20369/20369
# 100%|██████████| 20369/20369 [00:10<00:00, 1867.71it/s]
#    csi_matrix_r1_c2: 成功 20369/20369
# 100%|██████████| 20369/20369 [00:10<00:00, 1852.24it/s]
#    csi_matrix_r1_c3: 成功 20369/20369
# [3/6] 拼接原始数值/类别/元信息
# [4/6] 逐行筛选：至少 H 或任一 CSI 成功
#    保留 20369/20369 行
# [5/6] PreTab 编码：数值(ple) / 分类(one-hot) + 预清洗（分类任务适配）
#    [数值] 删除常数列: 9
# [6/6] 汇总编码结果 → DataFrame（分类任务适配）
#    [警告] 数值路 PreTab 失败，将使用未编码的清洗数值特征返回。
#    错误信息: TypeError("PLETransformer.fit() missing 1 required positional argument: 'y'")
#    数值路列数(输入): 237
#    分类路列数(输入): 1
# 完成 ✅ 输出形状： (20369, 241)

# %%
full_df.to_csv('/mnt/j/workspace/2025math/datasets/valid_pre_non_txbf.csv', index=False)
